# %%
# Libraries

import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Input
from tensorflow.keras.models import Sequential, Model
from skimage.transform import resize
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# Load the MNIST dataset
(train_X, train_y), (test_X, test_y) = mnist.load_data()

# Data preprocessing

train_X = train_X.astype('float32') / 255.0
train_y = to_categorical(train_y, num_classes=10)

# Evaluate the model on the test set

test_X = test_X.astype('float32') / 255.0
test_y = to_categorical(test_y, num_classes=10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
def mod_checkpoint_callback() -> None:

    trained_model = ModelCheckpoint(filepath = '/model.h5',  # result file name
                             save_weights_only = False,     # Save all training results/params.
                             monitor = 'val_accuracy',      # check our model accuracy if it's step forward.
                             mode = 'auto',                 # enable auto save.
                             save_best_only = True,         # if ac_new > ac_old
                             verbose = 1)
    return trained_model
model_checkpoint_callback = mod_checkpoint_callback()

# %%
# Create the model
def create_model():
  input_shape = (28, 28,1)
  
  model_seq = Sequential()

  # CNN 
  model_seq.add(Conv2D(8, kernel_size=(3, 3), activation='relu',padding='same', input_shape=input_shape))
  model_seq.add(MaxPooling2D(pool_size=(2, 2)))
  model_seq.add(Conv2D(8, kernel_size=(3, 3), activation='relu',padding='same'))
  model_seq.add(MaxPooling2D(pool_size=(2, 2)))
  model_seq.add(Conv2D(16, kernel_size=(3, 3), activation='relu',padding='same'))
  model_seq.add(MaxPooling2D(pool_size=(2, 2)))
  model_seq.add(Conv2D(32, kernel_size=(3, 3), activation='relu',padding='same'))
  model_seq.add(MaxPooling2D(pool_size=(2, 2)))


  # flatten layer
  model_seq.add(Flatten())

  # fully connected layers
  model_seq.add(Dense(72, activation='relu'))
  model_seq.add(Dropout(0.3))
  model_seq.add(Dense(10, activation='softmax', name='digit_out'))

  # model
  optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
  model_seq.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
  
  return model_seq

model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 8)         80
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 8)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 8)         584
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 8)          0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 16)          1168
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 16)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 3, 3, 32)          4640
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense (Dense)               (None, 72)                2376
#
#  dropout (Dropout)           (None, 72)                0
#
#  digit_out (Dense)           (None, 10)                730
#
# =================================================================
# Total params: 9,578
# Trainable params: 9,578
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
model.fit(train_X, train_y, epochs=50, batch_size=32, callbacks = [model_checkpoint_callback],validation_split=0.3)
# Out:
# Epoch 1/50
# 1313/1313 [==============================] - ETA: 0s - loss: 0.4793 - accuracy: 0.8452
# Epoch 1: val_accuracy improved from -inf to 0.95333, saving model to /model.h5
# 1313/1313 [==============================] - 21s 7ms/step - loss: 0.4793 - accuracy: 0.8452 - val_loss: 0.1462 - val_accuracy: 0.9533
# Epoch 2/50
# 1310/1313 [============================>.] - ETA: 0s - loss: 0.1565 - accuracy: 0.9535
# Epoch 2: val_accuracy improved from 0.95333 to 0.96850, saving model to /model.h5
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.1567 - accuracy: 0.9534 - val_loss: 0.1040 - val_accuracy: 0.9685
# Epoch 3/50
# 1309/1313 [============================>.] - ETA: 0s - loss: 0.1158 - accuracy: 0.9654
# Epoch 3: val_accuracy improved from 0.96850 to 0.97433, saving model to /model.h5
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.1157 - accuracy: 0.9655 - val_loss: 0.0877 - val_accuracy: 0.9743
# Epoch 4/50
# 1312/1313 [============================>.] - ETA: 0s - loss: 0.0967 - accuracy: 0.9712
# Epoch 4: val_accuracy improved from 0.97433 to 0.97750, saving model to /model.h5
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.0967 - accuracy: 0.9712 - val_loss: 0.0733 - val_accuracy: 0.9775
# Epoch 5/50
# 1307/1313 [============================>.] - ETA: 0s - loss: 0.0860 - accuracy: 0.9746
# Epoch 5: val_accuracy did not improve from 0.97750
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0864 - accuracy: 0.9746 - val_loss: 0.0864 - val_accuracy: 0.9756
# Epoch 6/50
# 1311/1313 [============================>.] - ETA: 0s - loss: 0.0745 - accuracy: 0.9782
# Epoch 6: val_accuracy improved from 0.97750 to 0.97972, saving model to /model.h5
# 1313/1313 [==============================] - 9s 7ms/step - loss: 0.0746 - accuracy: 0.9781 - val_loss: 0.0683 - val_accuracy: 0.9797
# Epoch 7/50
# 1306/1313 [============================>.] - ETA: 0s - loss: 0.0628 - accuracy: 0.9813
# Epoch 7: val_accuracy improved from 0.97972 to 0.98161, saving model to /model.h5
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.0630 - accuracy: 0.9813 - val_loss: 0.0606 - val_accuracy: 0.9816
# Epoch 8/50
# 1304/1313 [============================>.] - ETA: 0s - loss: 0.0586 - accuracy: 0.9819
# Epoch 8: val_accuracy did not improve from 0.98161
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0589 - accuracy: 0.9819 - val_loss: 0.0749 - val_accuracy: 0.9771
# Epoch 9/50
# 1304/1313 [============================>.] - ETA: 0s - loss: 0.0565 - accuracy: 0.9826
# Epoch 9: val_accuracy improved from 0.98161 to 0.98172, saving model to /model.h5
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0565 - accuracy: 0.9826 - val_loss: 0.0632 - val_accuracy: 0.9817
# Epoch 10/50
# 1307/1313 [============================>.] - ETA: 0s - loss: 0.0549 - accuracy: 0.9836
# Epoch 10: val_accuracy improved from 0.98172 to 0.98339, saving model to /model.h5
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.0549 - accuracy: 0.9835 - val_loss: 0.0610 - val_accuracy: 0.9834
# Epoch 11/50
# 1312/1313 [============================>.] - ETA: 0s - loss: 0.0500 - accuracy: 0.9855
# Epoch 11: val_accuracy improved from 0.98339 to 0.98350, saving model to /model.h5
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0499 - accuracy: 0.9855 - val_loss: 0.0584 - val_accuracy: 0.9835
# Epoch 12/50
# 1304/1313 [============================>.] - ETA: 0s - loss: 0.0480 - accuracy: 0.9848
# Epoch 12: val_accuracy did not improve from 0.98350
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.0482 - accuracy: 0.9847 - val_loss: 0.0793 - val_accuracy: 0.9776
# Epoch 13/50
# 1309/1313 [============================>.] - ETA: 0s - loss: 0.0434 - accuracy: 0.9865
# Epoch 13: val_accuracy improved from 0.98350 to 0.98600, saving model to /model.h5
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0436 - accuracy: 0.9865 - val_loss: 0.0513 - val_accuracy: 0.9860
# Epoch 14/50
# 1313/1313 [==============================] - ETA: 0s - loss: 0.0412 - accuracy: 0.9871
# Epoch 14: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0412 - accuracy: 0.9871 - val_loss: 0.0686 - val_accuracy: 0.9812
# Epoch 15/50
# 1306/1313 [============================>.] - ETA: 0s - loss: 0.0385 - accuracy: 0.9876
# Epoch 15: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.0385 - accuracy: 0.9876 - val_loss: 0.0676 - val_accuracy: 0.9823
# Epoch 16/50
# 1307/1313 [============================>.] - ETA: 0s - loss: 0.0353 - accuracy: 0.9885
# Epoch 16: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0354 - accuracy: 0.9885 - val_loss: 0.0627 - val_accuracy: 0.9842
# Epoch 17/50
# 1303/1313 [============================>.] - ETA: 0s - loss: 0.0342 - accuracy: 0.9892
# Epoch 17: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.0344 - accuracy: 0.9892 - val_loss: 0.0637 - val_accuracy: 0.9835
# Epoch 18/50
# 1303/1313 [============================>.] - ETA: 0s - loss: 0.0338 - accuracy: 0.9899
# Epoch 18: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0340 - accuracy: 0.9898 - val_loss: 0.0562 - val_accuracy: 0.9857
# Epoch 19/50
# 1311/1313 [============================>.] - ETA: 0s - loss: 0.0322 - accuracy: 0.9900
# Epoch 19: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0321 - accuracy: 0.9900 - val_loss: 0.0618 - val_accuracy: 0.9844
# Epoch 20/50
# 1313/1313 [==============================] - ETA: 0s - loss: 0.0315 - accuracy: 0.9903
# Epoch 20: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.0315 - accuracy: 0.9903 - val_loss: 0.0641 - val_accuracy: 0.9831
# Epoch 21/50
# 1313/1313 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9908
# Epoch 21: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0285 - accuracy: 0.9908 - val_loss: 0.0772 - val_accuracy: 0.9819
# Epoch 22/50
# 1303/1313 [============================>.] - ETA: 0s - loss: 0.0288 - accuracy: 0.9912
# Epoch 22: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0287 - accuracy: 0.9912 - val_loss: 0.0716 - val_accuracy: 0.9827
# Epoch 23/50
# 1306/1313 [============================>.] - ETA: 0s - loss: 0.0264 - accuracy: 0.9916
# Epoch 23: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.0263 - accuracy: 0.9916 - val_loss: 0.0659 - val_accuracy: 0.9839
# Epoch 24/50
# 1310/1313 [============================>.] - ETA: 0s - loss: 0.0262 - accuracy: 0.9916
# Epoch 24: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0262 - accuracy: 0.9916 - val_loss: 0.0695 - val_accuracy: 0.9833
# Epoch 25/50
# 1313/1313 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9925
# Epoch 25: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.0233 - accuracy: 0.9925 - val_loss: 0.0741 - val_accuracy: 0.9832
# Epoch 26/50
# 1307/1313 [============================>.] - ETA: 0s - loss: 0.0242 - accuracy: 0.9923
# Epoch 26: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0242 - accuracy: 0.9923 - val_loss: 0.0778 - val_accuracy: 0.9829
# Epoch 27/50
# 1306/1313 [============================>.] - ETA: 0s - loss: 0.0228 - accuracy: 0.9927
# Epoch 27: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0227 - accuracy: 0.9927 - val_loss: 0.0830 - val_accuracy: 0.9829
# Epoch 28/50
# 1313/1313 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9927
# Epoch 28: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.0227 - accuracy: 0.9927 - val_loss: 0.0636 - val_accuracy: 0.9857
# Epoch 29/50
# 1303/1313 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 0.9921
# Epoch 29: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0249 - accuracy: 0.9920 - val_loss: 0.0905 - val_accuracy: 0.9791
# Epoch 30/50
# 1311/1313 [============================>.] - ETA: 0s - loss: 0.0214 - accuracy: 0.9931
# Epoch 30: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.0214 - accuracy: 0.9931 - val_loss: 0.0589 - val_accuracy: 0.9856
# Epoch 31/50
# 1311/1313 [============================>.] - ETA: 0s - loss: 0.0205 - accuracy: 0.9934
# Epoch 31: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0206 - accuracy: 0.9934 - val_loss: 0.0713 - val_accuracy: 0.9838
# Epoch 32/50
# 1304/1313 [============================>.] - ETA: 0s - loss: 0.0200 - accuracy: 0.9938
# Epoch 32: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0199 - accuracy: 0.9938 - val_loss: 0.0774 - val_accuracy: 0.9818
# Epoch 33/50
# 1310/1313 [============================>.] - ETA: 0s - loss: 0.0193 - accuracy: 0.9938
# Epoch 33: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.0193 - accuracy: 0.9938 - val_loss: 0.0738 - val_accuracy: 0.9824
# Epoch 34/50
# 1308/1313 [============================>.] - ETA: 0s - loss: 0.0206 - accuracy: 0.9935
# Epoch 34: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0206 - accuracy: 0.9935 - val_loss: 0.0999 - val_accuracy: 0.9817
# Epoch 35/50
# 1307/1313 [============================>.] - ETA: 0s - loss: 0.0175 - accuracy: 0.9944
# Epoch 35: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.0177 - accuracy: 0.9944 - val_loss: 0.0809 - val_accuracy: 0.9829
# Epoch 36/50
# 1303/1313 [============================>.] - ETA: 0s - loss: 0.0205 - accuracy: 0.9936
# Epoch 36: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0205 - accuracy: 0.9936 - val_loss: 0.0641 - val_accuracy: 0.9860
# Epoch 37/50
# 1308/1313 [============================>.] - ETA: 0s - loss: 0.0172 - accuracy: 0.9944
# Epoch 37: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0172 - accuracy: 0.9944 - val_loss: 0.0875 - val_accuracy: 0.9817
# Epoch 38/50
# 1310/1313 [============================>.] - ETA: 0s - loss: 0.0178 - accuracy: 0.9943
# Epoch 38: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.0178 - accuracy: 0.9943 - val_loss: 0.0763 - val_accuracy: 0.9847
# Epoch 39/50
# 1307/1313 [============================>.] - ETA: 0s - loss: 0.0189 - accuracy: 0.9944
# Epoch 39: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0189 - accuracy: 0.9944 - val_loss: 0.0725 - val_accuracy: 0.9854
# Epoch 40/50
# 1306/1313 [============================>.] - ETA: 0s - loss: 0.0164 - accuracy: 0.9946
# Epoch 40: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.0163 - accuracy: 0.9947 - val_loss: 0.0895 - val_accuracy: 0.9833
# Epoch 41/50
# 1304/1313 [============================>.] - ETA: 0s - loss: 0.0177 - accuracy: 0.9942
# Epoch 41: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0177 - accuracy: 0.9942 - val_loss: 0.0838 - val_accuracy: 0.9844
# Epoch 42/50
# 1306/1313 [============================>.] - ETA: 0s - loss: 0.0144 - accuracy: 0.9954
# Epoch 42: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 9s 7ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 0.0763 - val_accuracy: 0.9842
# Epoch 43/50
# 1307/1313 [============================>.] - ETA: 0s - loss: 0.0177 - accuracy: 0.9941
# Epoch 43: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.0177 - accuracy: 0.9941 - val_loss: 0.0810 - val_accuracy: 0.9842
# Epoch 44/50
# 1302/1313 [============================>.] - ETA: 0s - loss: 0.0178 - accuracy: 0.9942
# Epoch 44: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0181 - accuracy: 0.9941 - val_loss: 0.0818 - val_accuracy: 0.9837
# Epoch 45/50
# 1310/1313 [============================>.] - ETA: 0s - loss: 0.0146 - accuracy: 0.9949
# Epoch 45: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0146 - accuracy: 0.9949 - val_loss: 0.0785 - val_accuracy: 0.9848
# Epoch 46/50
# 1312/1313 [============================>.] - ETA: 0s - loss: 0.0169 - accuracy: 0.9945
# Epoch 46: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.0169 - accuracy: 0.9945 - val_loss: 0.0702 - val_accuracy: 0.9856
# Epoch 47/50
# 1304/1313 [============================>.] - ETA: 0s - loss: 0.0165 - accuracy: 0.9949
# Epoch 47: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0164 - accuracy: 0.9950 - val_loss: 0.0872 - val_accuracy: 0.9843
# Epoch 48/50
# 1312/1313 [============================>.] - ETA: 0s - loss: 0.0122 - accuracy: 0.9957
# Epoch 48: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.0122 - accuracy: 0.9957 - val_loss: 0.0965 - val_accuracy: 0.9842
# Epoch 49/50
# 1306/1313 [============================>.] - ETA: 0s - loss: 0.0161 - accuracy: 0.9952
# Epoch 49: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 7s 6ms/step - loss: 0.0162 - accuracy: 0.9951 - val_loss: 0.0946 - val_accuracy: 0.9837
# Epoch 50/50
# 1305/1313 [============================>.] - ETA: 0s - loss: 0.0148 - accuracy: 0.9954
# Epoch 50: val_accuracy did not improve from 0.98600
# 1313/1313 [==============================] - 9s 7ms/step - loss: 0.0147 - accuracy: 0.9954 - val_loss: 0.0890 - val_accuracy: 0.9844

# %%
model.evaluate(test_X, test_y)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0708 - accuracy: 0.9874
# [0.07078444212675095, 0.9873999953269958]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision.datasets import MNIST
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader
from torchvision.utils import make_grid
import matplotlib.pyplot as plt

# Load the MNIST dataset
train_dataset = MNIST(root='data/', train=True, transform=ToTensor(), download=True)
test_dataset = MNIST(root='data/', train=False, transform=ToTensor())

# Data preprocessing
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Define the model
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=8, kernel_size=3, padding=1)
        self.pool1 = nn.MaxPool2d(kernel_size=2)
        self.conv2 = nn.Conv2d(in_channels=8, out_channels=8, kernel_size=3, padding=1)
        self.pool2 = nn.MaxPool2d(kernel_size=2)
        self.conv3 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, padding=1)
        self.pool3 = nn.MaxPool2d(kernel_size=2)
        self.conv4 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=1)
        self.pool4 = nn.MaxPool2d(kernel_size=2)
        
        self.flatten = nn.Flatten()
        
        self.fc1 = nn.Linear(in_features=32*1*1, out_features=72)
        self.dropout = nn.Dropout(0.3)
        self.fc2 = nn.Linear(in_features=72, out_features=10)
    
    def forward(self, x):
        x = self.pool1(torch.relu(self.conv1(x)))
        x = self.pool2(torch.relu(self.conv2(x)))
        x = self.pool3(torch.relu(self.conv3(x)))
        x = self.pool4(torch.relu(self.conv4(x)))
        
        x = self.flatten(x)
        
        x = torch.relu(self.fc1(x))
        x = self.dropout(x)
        x = torch.softmax(self.fc2(x), dim=1)
        
        return x

# Create the model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CNN().to(device)
print(model)

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 50
for epoch in range(num_epochs):
    running_loss = 0.0
    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)
        
        optimizer.zero_grad()
        
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(train_loader):.4f}")

# Evaluation
model.eval()
total_correct = 0
total_samples = 0
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        
        outputs = model(images)
        _, predicted = torch.max(outputs, dim=1)
        total_correct += (predicted == labels).sum().item()
        total_samples += labels.size(0)
# Out:
# CNN(
#   (conv1): Conv2d(1, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=32, out_features=72, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc2): Linear(in_features=72, out_features=10, bias=True)
# )
# Epoch [1/50], Loss: 1.6899
# Epoch [2/50], Loss: 1.5365
# Epoch [3/50], Loss: 1.5151
# Epoch [4/50], Loss: 1.5064
# Epoch [5/50], Loss: 1.5005
# Epoch [6/50], Loss: 1.4979
# Epoch [7/50], Loss: 1.4945
# Epoch [8/50], Loss: 1.4932
# Epoch [9/50], Loss: 1.4910
# Epoch [10/50], Loss: 1.4891
# Epoch [11/50], Loss: 1.4878
# Epoch [12/50], Loss: 1.4881
# Epoch [13/50], Loss: 1.4880
# Epoch [14/50], Loss: 1.4867
# Epoch [15/50], Loss: 1.4882
# Epoch [16/50], Loss: 1.4856
# Epoch [17/50], Loss: 1.4864
# Epoch [18/50], Loss: 1.4855
# Epoch [19/50], Loss: 1.4848
# Epoch [20/50], Loss: 1.4852
# Epoch [21/50], Loss: 1.4839
# Epoch [22/50], Loss: 1.4840
# Epoch [23/50], Loss: 1.4836
# Epoch [24/50], Loss: 1.4851
# Epoch [25/50], Loss: 1.4833
# Epoch [26/50], Loss: 1.4838
# Epoch [27/50], Loss: 1.4842
# Epoch [28/50], Loss: 1.4844
# Epoch [29/50], Loss: 1.4856
# Epoch [30/50], Loss: 1.4847
# Epoch [31/50], Loss: 1.4830
# Epoch [32/50], Loss: 1.4826
# Epoch [33/50], Loss: 1.4841
# Epoch [34/50], Loss: 1.4828
# Epoch [35/50], Loss: 1.4813
# Epoch [36/50], Loss: 1.4830
# Epoch [37/50], Loss: 1.4836
# Epoch [38/50], Loss: 1.4836
# Epoch [39/50], Loss: 1.4841
# Epoch [40/50], Loss: 1.4856
# Epoch [41/50], Loss: 1.4837
# Epoch [42/50], Loss: 1.4827
# Epoch [43/50], Loss: 1.4838
# Epoch [44/50], Loss: 1.4837
# Epoch [45/50], Loss: 1.4829
# Epoch [46/50], Loss: 1.4835
# Epoch [47/50], Loss: 1.4833
# Epoch [48/50], Loss: 1.4831
# Epoch [49/50], Loss: 1.4846
# Epoch [50/50], Loss: 1.4839

# %%
model.eval()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-67f96fad7f04> in <cell line: 1>()
# ----> 1 model.eval()
#
# NameError: name 'model' is not defined
